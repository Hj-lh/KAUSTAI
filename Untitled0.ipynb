# %%
print("hello ML")
# Out:
# hello ML

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Household energy bill data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-87e11b8d63a9> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/Household energy bill data.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2a851eda2e88> in <cell line: 1>()
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
df['amount_paid'] = df['amount_paid'] * 2
# Out:
#      num_rooms  num_people  housearea  is_ac  is_tv  is_flat  \
# 0            3           3     742.57      1      1        1
# 1            1           5     952.99      0      1        0
# 2            3           1     761.44      1      1        1
# 3            0           5     861.32      1      1        0
# 4            1           8     731.61      0      1        0
# ..         ...         ...        ...    ...    ...      ...
# 995          3           0     991.31      0      1        0
# 996          2           5     847.97      0      1        0
# 997          2           4     660.94      1      0        0
# 998          1           1     814.75      0      1        1
# 999          1           6     835.43      0      0        0
#
#      ave_monthly_income  num_children  is_urban   amount_paid
# 0               9675.93             2         0   8967.703150
# 1              35064.79             1         1  10132.538858
# ...

# %%
meanOfColumn = df['amount_paid'].mean()
print(meanOfColumn)

df['childANDpeople'] = df['num_people']+df['num_children']
# Out:
# 600.3963593265801

# %%
df.plot.scatter(x='childANDpeople',y='amount_paid',colormap='viridis', s=50,alpha =0.5)
df.plot.scatter(x='housearea',y='amount_paid',colormap='viridis', s=50,alpha =0.5)
# Out:
# <Axes: xlabel='housearea', ylabel='amount_paid'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['num_people', 'num_children', 'housearea']], df['amount_paid'], test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
new_data = [[3, 1, 150]]
predicted_amount_paid = model.predict(new_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
